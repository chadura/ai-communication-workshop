# %%
import numpy as np
import pandas as pd
import joblib
import sklearn

import matplotlib.pyplot as plt

# %%
sklearn.__version__
# Out:
# '1.7.2'

# %% [markdown]
# 1. Load data
# 2. build classifier
# 3. Export model snapshot
# 4. Load snapshort into fastAPI
# 5. Run API and call from streamlit

# %%
data = pd.read_csv('demos/sentiment-api/data/sentiment_sample.csv', sep=',', nrows=35)

# %%
data.head()
# Out:
#                                                 text sentiment
# 0        Your order has been successfully delivered!  positive
# 1                Thank you for choosing our service!  positive
# 2  We appreciate your feedback and look forward t...  positive
# 3  Congratulations! You've been selected for a re...  positive
# 4            Your payment was received successfully.  positive

# %%
data.sentiment)
# Out:
# 35

# %%
plt.barh(data.sentiment, width=4)
# Out:
# <BarContainer object of 35 artists>

# %%
labels = data.sentiment
text = data.text
