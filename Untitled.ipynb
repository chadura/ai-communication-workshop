# %%
a = 9

b = 6

# %%
name = "Monty"

# %%
name
# Out:
# 'Monty'

# %%
a
# Out:
# 9

# %%
def 8x():
    pass
# Out:
#   Cell In[5], line 1
#     def 8x():
#         ^
# SyntaxError: invalid decimal literal

# %%
def function_one():
    print(8)

# %%
function_one()
# Out:
# 8

# %%
def power_2(x):
    print(x ** x)

# %%
power_2(2)
# Out:
# 4

# %%
power_2(3.0)
# Out:
# 27.0

# %%
power_2('r')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 power_2('r')
#
# Cell In[9], line 2, in power_2(x)
#       1 def power_2(x):
# ----> 2     print(x ** x)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'str'

# %%
power_2(r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 power_2(r)
#
# NameError: name 'r' is not defined

# %%
power_2(b)
# Out:
# 46656

# %%
def add(x, y):
    return x + y

# %%
x = add(a, b)

# %%
x
# Out:
# 15

# %%
def add(x, y=4):
    return x + y

# %%
x = add(a, b)

# %%
x = add(a)

# %%
l1 = [1, 4, 6, 8, 12, 24, 36]

# %%
for x in l1:
    power_2(x)
# Out:
# 1
# 256
# 46656
# 16777216
# 8916100448256
# 1333735776850284124449081472843776
# 106387358923716524807713475752456393740167855629859291136

# %%
class Person:

    def add(x, y):
        return x+y

    def sub(x, y):
        return x - y

# %%
type(Person)
# Out:
# type

# %%
Person.add(a, b)
# Out:
# 15

# %%
import os
import sys

# %%
print(sys.version)
# Out:
# 3.12.11 (main, Jun  3 2025, 15:41:47) [Clang 17.0.0 (clang-1700.0.13.3)]

# %%
import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 import keras
#
# ModuleNotFoundError: No module named 'keras'

# %%
# !pip install keras
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 31.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 29.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 kB 26.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [keras]8;5;237m━━━━ 8/9 [keras]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
